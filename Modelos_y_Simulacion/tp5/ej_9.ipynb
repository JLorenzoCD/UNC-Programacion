# %%
import math
import numpy as np

# %% [markdown]
# ### Ejercicio 9.
# a. generación de variables exponenciales según el ejemplo 5 f del libro Simulacion de S. M. Ross,
#
# b. el método polar,
#
# c. el método de razón entre uniformes.
#
# Pruebe los códigos calculando la media muestral y varianza muestral de 10.000 valores generados con los
# tres métodos.

# %% [markdown]
# ---

# %%
def punto_a_Exp(lamda: float):
    pass


def punto_b_MP(x_mu: float = 0.0, x_sigma: float = 1.0, y_mu: float = 0.0, y_sigma: float = 1.0):
    Rcuadrado = -2 * math.log(1 - np.random.random())
    Theta = 2 * math.pi * np.random.random()

    X = math.sqrt(Rcuadrado) * math.cos(Theta)
    Y = math.sqrt(Rcuadrado) * math.sin(Theta)

    return (X * x_sigma + x_mu, Y * y_sigma + y_mu)


def punto_c_MReU(mu: float = 0.0, sigma: float = 1.0):
    pass
